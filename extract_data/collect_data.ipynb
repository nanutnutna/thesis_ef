# %%
import requests
from bs4 import BeautifulSoup
import urllib3
import pandas as pd
from tqdm import tqdm
from pathlib import Path
import numpy as np

# %%
# URL to scrape
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
url = "https://thaicarbonlabel.tgo.or.th/index.php?lang=TH&mod=Y0hKdlpIVmpkSE5mWlcxcGMzTnBiMjQ9"

# Send a GET request
response = requests.get(url, verify=False)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'lxml')
    table = soup.find("table",{"class":"table table-striped table-bordered table-hover table-full-width table-customize"})
    dfs = pd.read_html(str(table))[0]
else:
    print(f"Failed to fetch page, status code: {response.status_code}")
# Out:
# C:\Users\Nattapot\AppData\Local\Temp\ipykernel_24864\214197682.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(table))[0]

# %%
output = r'C:\Users\Nattapot\Desktop\thesis_ef\emission_factor_2'
dfs.to_csv(f'{output}.csv',index=False,encoding='utf-8-sig')

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
url = "https://thaicarbonlabel.tgo.or.th/index.php?lang=TH&mod=YjNKbllXNXBlbUYwYVc5dVgyVnRhWE56YVc5dQ"


response = requests.get(url, verify=False)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'lxml')
    table = soup.find("table")
    dfs = pd.read_html(str(table),header=[1,2])[0]
    dfs.columns = [" ".join(col).strip() if "unit" in col[1] else col[0] for col in dfs.columns]
else:
    print(f"Failed to fetch page, status code: {response.status_code}")
# Out:
# C:\Users\Nattapot\AppData\Local\Temp\ipykernel_24864\3730854390.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(table),header=[1,2])[0]

# %%
dfs['Description'] = dfs['ลำดับ']
dfs['Description'] = dfs['Description'].fillna(dfs['ชื่อ'])
dfs.loc[1:23, 'Description'] = 'Stationary Combustion'
dfs.loc[24:31, 'Description'] = 'Mobile Combustion (On road)'
dfs.loc[31:37, 'Description'] = 'Mobile Combustion (Off road), Diesel'
dfs.loc[38:42, 'Description'] = 'Mobile Combustion (On road), Motor Gasoline 4 stroke'
dfs.loc[43:47, 'Description'] = 'Mobile Combustion (On road), Motor Gasoline 2 stroke'
dfs.loc[48, 'Description'] = 'Electricity, grid mix (ไฟฟ้า)'
dfs.loc[50:, 'Description'] = 'Refrigerants (สารทำความเย็น)'
dfs['ลำดับ'] = pd.to_numeric(dfs['ลำดับ'], errors='coerce')
dfs = dfs.dropna(subset=['ลำดับ'])
dfs = dfs.drop(columns=['CO2 [kg CO2/unit]','Fossil CH4 [kg CH4/unit]','CH4 [kg CH4/unit]','N2O [kg N2O/unit]'])
# Out:
#     ลำดับ                                               ชื่อ  หน่วย  \
# 1     1.0                                        Natural gas    scf
# 2     2.0                                        Natural gas     MJ
# 3     3.0                                            Lignite     kg
# 4     4.0                                         Fuel oil A  litre
# 5     5.0                                         Fuel oil C  litre
# 6     6.0                                     Gas/Diesel oil  litre
# 7     7.0                                         Anthracite     kg
# 8     8.0                                Sub-bituminous coal     kg
# 9     9.0                                       Jet Kerosene  litre
# 10   10.0                                                LPG  litre
# 11   11.0                                                LPG     kg
# 12   12.0                                     Motor gasoline  litre
# 13   13.0                                          FUEL WOOD     kg
# 14   14.0                                            Bagasse     kg
# 15   15.0                                  Palm kernel shell     kg
# 16   16.0                                                Cob     kg
# 17   17.0                                             Biogas     m3
# 18   18.0                                FUEL WOOD (CO2only)     kg
# 19   19.0                                  Bagasse (CO2only)     kg
# 20   20.0                        Palm kernel shell (CO2only)     kg
# 21   21.0                                      Cob (CO2only)     kg
# 22   22.0                                   Biogas (CO2only)     m3
# 24   23.0                      Motor Gasoline - uncontrolled  litre
# 25   24.0                Motor Gasoline - oxydation catalyst  litre
# 26   25.0  Motor Gasoline - low mileage light duty vihicl...  litre
# 27   26.0                                    Gas/ Diesel Oil  litre
# 28   27.0                             Compressed Natural Gas     kg
# 29   28.0                            Liquified Petroleum Gas  litre
# 30   29.0                            Liquified Petroleum Gas     kg
# 33   30.0                                        Agriculture  litre
# 34   31.0                                           Forestry  litre
# 35   32.0                                           Industry  litre
# 36   33.0                                          Household  litre
# 38   34.0                                        Agriculture  litre
# 39   35.0                                           Forestry  litre
# 40   36.0                                           Industry  litre
# 41   37.0                                          Household  litre
# 43   38.0                                        Agriculture  litre
# 44   39.0                                           Forestry  litre
# 45   40.0                                           Industry  litre
# 46   41.0                                          Household  litre
# 48   42.0  ไฟฟ้าแบบ grid mix ปี 2016-2018; LCIA method IP...    kWh
# 50   43.0                                     R-22 (HCFC-22)     kg
# 51   44.0                                               R-32     kg
# 52   45.0                                              R-125     kg
# 53   46.0                                              R-134     kg
# 54   47.0                                             R-134a     kg
# 55   48.0                                              R-143     kg
# 56   49.0                                             R-143a     kg
#
#    Total [kg CO2eq/unit]                                      ข้อมูลอ้างอิง  \
# 1             0.05727963                         IPCC Vol.2 table 2.2, DEDE
# 2              0.0561565                         IPCC Vol.2 table 2.2, DEDE
# 3            1.061945925                         IPCC Vol.2 table 2.2, DEDE
# 4       3.22002421843653                          IPCC Vol.2 table 2.2, PTT
# 5       3.24574836560836                          IPCC Vol.2 table 2.2, PTT
# 6             2.70779058                         IPCC Vol.2 table 2.2, DEDE
# 7              3.1000435                         IPCC Vol.2 table 2.2, DEDE
# 8            2.545430175                         IPCC Vol.2 table 2.2, DEDE
# 9             2.47749297                         IPCC Vol.2 table 2.2, DEDE
# 10            1.68122603                         IPCC Vol.2 table 2.2, DEDE
# 11      3.11338153703704   IPCC Vol.2 table 2.2, DEDE LPG 1 litre = 0.54 kg
# 12            2.18940252                         IPCC Vol.2 table 2.2, DEDE
# 13              0.030381                         IPCC Vol.2 table 2.2, DEDE
# 14              0.014307                         IPCC Vol.2 table 2.2, DEDE
# 15              0.035207                         IPCC Vol.2 table 2.2, DEDE
# 16              0.031882                         IPCC Vol.2 table 2.2, DEDE
# 17           0.001140685                         IPCC Vol.2 table 2.2, DEDE
# 18               1.79088                         IPCC Vol.2 table 2.2, DEDE
# 19                 0.753                         IPCC Vol.2 table 2.2, DEDE
# 20                 1.853                         IPCC Vol.2 table 2.2, DEDE
# 21                 1.678                         IPCC Vol.2 table 2.2, DEDE
# 22              1.142778                         IPCC Vol.2 table 2.2, DEDE
# 24            2.23942424                IPCC Vol.2 table 3.2.1, 3.2.2, DEDE
# 25             2.2719116                IPCC Vol.2 table 3.2.1, 3.2.2, DEDE
# 26            2.23270326                IPCC Vol.2 table 3.2.1, 3.2.2, DEDE
# 27            2.74062321                IPCC Vol.2 table 3.2.1, 3.2.2, DEDE
# 28             2.2609245                 IPCC Vol.2 table 3.2.1, 3.2.2, PTT
# 29            1.73064606                IPCC Vol.2 table 3.2.1, 3.2.2, DEDE
# 30      3.20490011111111  IPCC Vol.2 table 3.2.1, 3.2.2, DEDE LPG 1 litr...
# 33            2.97928347                       IPCC Vol.2 table 3.3.1, DEDE
# 34            2.97928347                       IPCC Vol.2 table 3.3.1, DEDE
# 35            2.97928347                       IPCC Vol.2 table 3.3.1, DEDE
# 36            2.97928347                       IPCC Vol.2 table 3.3.1, DEDE
# 38             2.2738004                       IPCC Vol.2 table 3.3.1, DEDE
# 39              2.181564                       IPCC Vol.2 table 3.3.1, DEDE
# 40             2.2454684                       IPCC Vol.2 table 3.3.1, DEDE
# 41             2.3115764                       IPCC Vol.2 table 3.3.1, DEDE
# 43            2.31711688                       IPCC Vol.2 table 3.3.1, DEDE
# 44            2.34544888                       IPCC Vol.2 table 3.3.1, DEDE
# 45            2.30767288                       IPCC Vol.2 table 3.3.1, DEDE
# 46            2.35489288                       IPCC Vol.2 table 3.3.1, DEDE
# 48                0.4999  Thai National LCI Database, TIISMTEC-NSTDA, AR...
# 50                  1760                                     IPCC 2013, AR5
# 51                   677                                     IPCC 2013, AR5
# 52                  3170                                     IPCC 2013, AR5
# 53                  1120                                     IPCC 2013, AR5
# 54                  1300                                     IPCC 2013, AR5
# 55                   328                                     IPCC 2013, AR5
# 56                  4800                                     IPCC 2013, AR5
#
#                                           Description
# 1                               Stationary Combustion
# 2                               Stationary Combustion
# 3                               Stationary Combustion
# 4                               Stationary Combustion
# 5                               Stationary Combustion
# 6                               Stationary Combustion
# 7                               Stationary Combustion
# 8                               Stationary Combustion
# 9                               Stationary Combustion
# 10                              Stationary Combustion
# 11                              Stationary Combustion
# 12                              Stationary Combustion
# 13                              Stationary Combustion
# 14                              Stationary Combustion
# 15                              Stationary Combustion
# 16                              Stationary Combustion
# 17                              Stationary Combustion
# 18                              Stationary Combustion
# 19                              Stationary Combustion
# 20                              Stationary Combustion
# 21                              Stationary Combustion
# 22                              Stationary Combustion
# 24                        Mobile Combustion (On road)
# 25                        Mobile Combustion (On road)
# 26                        Mobile Combustion (On road)
# 27                        Mobile Combustion (On road)
# 28                        Mobile Combustion (On road)
# 29                        Mobile Combustion (On road)
# 30                        Mobile Combustion (On road)
# 33               Mobile Combustion (Off road), Diesel
# 34               Mobile Combustion (Off road), Diesel
# 35               Mobile Combustion (Off road), Diesel
# 36               Mobile Combustion (Off road), Diesel
# 38  Mobile Combustion (On road), Motor Gasoline 4 ...
# 39  Mobile Combustion (On road), Motor Gasoline 4 ...
# 40  Mobile Combustion (On road), Motor Gasoline 4 ...
# 41  Mobile Combustion (On road), Motor Gasoline 4 ...
# 43  Mobile Combustion (On road), Motor Gasoline 2 ...
# 44  Mobile Combustion (On road), Motor Gasoline 2 ...
# 45  Mobile Combustion (On road), Motor Gasoline 2 ...
# 46  Mobile Combustion (On road), Motor Gasoline 2 ...
# 48                      Electricity, grid mix (ไฟฟ้า)
# 50                       Refrigerants (สารทำความเย็น)
# 51                       Refrigerants (สารทำความเย็น)
# 52                       Refrigerants (สารทำความเย็น)
# 53                       Refrigerants (สารทำความเย็น)
# 54                       Refrigerants (สารทำความเย็น)
# 55                       Refrigerants (สารทำความเย็น)
# 56                       Refrigerants (สารทำความเย็น)

# %%
dfs.to_csv()

# %%
# lst_license = []
# lst_imgs_url,lst_img_details = [],[]
# for num in tqdm(range(1,924)):
#     urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
#     # URL of the webpage
#     url = f'https://thaicarbonlabel.tgo.or.th/index.php?lang=TH&mod=Y0hKdlpIVmpkSE5mWVhCd2NtOTJZV3c9&page={num}'
#     response = requests.get(url, verify=False)
#     soup = BeautifulSoup(response.content, 'html.parser')

#     # License
#     license_p = soup.find_all(class_='approval-text-info')
#     for i, element in enumerate(license_p, start=1):
#         h4_tags = element.find_all('h4')  # Find all <h4> inside the current element
#         if h4_tags:
#             for h4 in h4_tags:
#                 lst_license.append(h4.text)
#         else:
#             print(f"Section {i}: No <h4> found inside this element.")

#     # Images
#     approval_text_elements = soup.find_all(class_='span9 approval-text')
#     for i, element in enumerate(approval_text_elements, start=1):
#         img_tags = element.find_all('img')  # Find all <img> inside the current element
#         if img_tags:
#             for img in img_tags:
#                 img_src = img.get('src')
#                 img_alt = img.get('alt', 'No alt attribute')
#                 lst_imgs_url.append(img_src)
#                 lst_img_details.append(img_alt)
#         else:
#             print(f"Section {i}: No <img> found inside this element.")


# df = pd.DataFrame({'License':lst_license,'img_URL':lst_imgs_url,'img_details':lst_img_details})
# df.to_csv('url_imges.csv',index=False,encoding='utf-8-sig')

# df = pd.read_csv("url_imges.csv")
# df

# %%
ef3 = pd.read_csv('../emission_factor_3.csv')
ef3 = ef3.dropna(subset=['เลขที่ใบรับรอง','ชื่อ','ปริมาณ CF'])
ef3 = ef3.drop(columns=['ลำดับ','ติดต่อ','โทรศัพท์','อีเมล์'])
ef3 = ef3.rename(columns={'อุตสาหกรรม':'กลุ่ม','ปริมาณ CF':'CF'})
ef3 = ef3.sort_values(by='เลขที่ใบรับรอง')
ef3['img_path'] = np.nan
image_path = r'C:\Users\Nattapot\Desktop\thesis_ef\app\backend\images'
image_name = Path(image_path)
img_files = [file.name.split('.')[0] for file in image_name.iterdir() if file.is_file()]
full_path_imgs = r'http://localhost:8000/static'
ef3['img_path'] = ef3['เลขที่ใบรับรอง'].apply(lambda x: f'{full_path_imgs}/{x}.jpg' if x in img_files else f"{full_path_imgs}/no_img_l.jpg")
path = r'C:\Users\Nattapot\Desktop\thesis_ef\emission_factor_3_use.csv'
ef3.to_csv(path,encoding='utf-8-sig',index=False)

# %%
ef3
# Out:
#               เลขที่ใบรับรอง  \
# 10731                    TGO
# 4174          TGO 16-048-237
# 10733               TGO 2553
# 5205        TGO 3-16-014-049
# 10730                 TGO CF
# ...                      ...
# 395    TGO CFP FY25-100-0824
# 1729   TGO CFP FY25-101-0825
# 1728   TGO CFP FY25-101-0826
# 8934    TGO CFR FY21-008-028
# 11566   TGO CFR FY21-025-109
#
#                                                     ชื่อ  รายละเอียด  \
# 10731            อาหารไก่เนื้อ ซีพี เบอร์ 511 (บรรจุถุง)         NaN
# 4174   ท่อพีวีซี เอสซีจี ระบบประปา-ระบายน้ำ-5 ปริมาตร...         NaN
# 10733            อาหารไก่เนื้อ ซีพี เบอร์ 531 (บรรจุถุง)         NaN
# 5205   น้ำมันถั่วเหลืองผ่านกรรมวิธี ตราองุ่น บรรจุในป...         NaN
# 10730            อาหารไก่เนื้อ ซีพี เบอร์ 510 (บรรจุถุง)         NaN
# ...                                                  ...         ...
# 395        CT1203A ก๊อกอ่างล้างหน้า แบบก้านโยก รุ่น EVER         NaN
# 1729             กรีนแคลไซส์ (ชนิดเม็ด) ขนาด 25 กิโลกรัม         NaN
# 1728              กรีนแคลแมก (ชนิดเม็ด) ขนาด 25 กิโลกรัม         NaN
# 8934                            สลากกินแบ่งรัฐบาล 1 ฉบับ         NaN
# 11566  เครื่องดื่มน้ำอัดลม เอส โคล่า บรรจุขวดแก้ว ขนา...         NaN
#
#            กลุ่ม วันที่อนุมัติ    ปริมาณ CF  \
# 10731      อาหาร    28/12/2553       9.1 kg
# 4174    ก่อสร้าง    27/07/2559       0.39 g
# 10733      อาหาร    28/12/2553         8 kg
# 5205       อาหาร    23/03/2559      7.51 kg
# 10730      อาหาร    28/12/2553       8.7 kg
# ...          ...           ...          ...
# 395     ก่อสร้าง    26/11/2567  65.5 kgCO2e
# 1729       อื่นๆ    26/11/2567   116 kgCO2e
# 1728       อื่นๆ    26/11/2567  84.7 kgCO2e
# 8934   สิ่งพิมพ์    25/02/2564   2.08 gCO2e
# 11566      อาหาร    27/10/2564    122 gCO2e
#
#                                            หน่วยการทำงาน ขอบเขต  \
# 10731                                        30 กิโลกรัม    B2B
# 4174                                    ปริมาตร 1 ลบ.ซม.    B2C
# 10733                                        30 กิโลกรัม    B2B
# 5205                                          13.75 ลิตร    B2C
# 10730                                        30 กิโลกรัม    B2B
# ...                                                  ...    ...
# 395    ต่อ การใช้งานสำหรับก๊อกน้ำ 100,000 ครั้ง ที่อา...    B2C
# 1729                                            1 กระสอบ    B2B
# 1728                                            1 กระสอบ    B2B
# 8934                                              1 ฉบับ    B2C
# 11566                                      1 ขวด 330 มล.    B2C
#
#                                                 img_path
# 10731               http://localhost:8000/static/TGO.jpg
# 4174     http://localhost:8000/static/TGO 16-048-237.jpg
# 10733          http://localhost:8000/static/TGO 2553.jpg
# 5205   http://localhost:8000/static/TGO 3-16-014-049.jpg
# 10730            http://localhost:8000/static/TGO CF.jpg
# ...                                                  ...
# 395    http://localhost:8000/static/TGO CFP FY25-100-...
# 1729   http://localhost:8000/static/TGO CFP FY25-101-...
# 1728   http://localhost:8000/static/TGO CFP FY25-101-...
# 8934   http://localhost:8000/static/TGO CFR FY21-008-...
# 11566  http://localhost:8000/static/TGO CFR FY21-025-...
#
# [10258 rows x 9 columns]

# %%
imgdf = pd.read_csv("../url_imges.csv")
imgdf
# Out:
#                         License  \
# 0      TGO CFP FY25-012-04-0046
# 1      TGO CFP FY25-012-03-0047
# 2      TGO CFP FY25-012-03-0048
# 3      TGO CFP FY25-015-02-0051
# 4      TGO CFP FY25-021-02-0081
# ...                         ...
# 11068      TGO CFP FY17-031-242
# 11069                         -
# 11070      TGO CFP FY21-068-403
# 11071      TGO CFP FY21-068-402
# 11072   TGO CFP FY21-070-02-410
#
#                                                  img_URL  \
# 0      https://thaicarbonlabel.tgo.or.th/admin/upload...
# 1      https://thaicarbonlabel.tgo.or.th/admin/upload...
# 2      https://thaicarbonlabel.tgo.or.th/admin/upload...
# 3      https://thaicarbonlabel.tgo.or.th/admin/upload...
# 4      https://thaicarbonlabel.tgo.or.th/admin/upload...
# ...                                                  ...
# 11068  https://thaicarbonlabel.tgo.or.th/admin/upload...
# 11069  https://thaicarbonlabel.tgo.or.th/assets/img/n...
# 11070  https://thaicarbonlabel.tgo.or.th/admin/upload...
# 11071  https://thaicarbonlabel.tgo.or.th/admin/upload...
# 11072  https://thaicarbonlabel.tgo.or.th/admin/upload...
#
#                                              img_details
# 0                           เส้นหมี่อบแห้ง ขนาด 180 กรัม
# 1                           เส้นหมี่อบแห้ง ขนาด 500 กรัม
# 2                         เส้นหมี่อบแห้ง ขนาด 2,700 กรัม
# 3      ข้าวหอมมะลิ 100% บรรจุถุง ตราฉัตร ขนาด 20 กิโล...
# 4            เบียร์ลีโอ บรรจุขวดแก้ว ขนาด 620 มิลลิลิตร
# ...                                                  ...
# 11068  สีน้ำโฟร์ซีซั่น ชนิดด้าน สำหรับทาภายนอก เบส เอ...
# 11069                                ขนมปังสอดไส้ถั่วแดง
# 11070       น้ำดื่มสิงห์ บรรจุขวดแก้ว ขนาด 500 มิลลิลิตร
# 11071     น้ำดื่มสิงห์ บรรจุขวด PET ขนาด 6,000 มิลลิลิตร
# 11072   น้ำดื่มตราคริสตัล บรรจุขวดพีอีที ขนาด 600 ลบ.ซม.
#
# [11073 rows x 3 columns]
