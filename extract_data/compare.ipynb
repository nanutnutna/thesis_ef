# %%
c = {}
with open('synonym_test.txt', 'r', encoding='utf-8') as file:
    synonyms_data = file.readlines()
    for w in synonyms_data:
        word = w.replace('\n','')
        for i in word.split(','):
            c[i] = c.get(i,0) + 1
    for key,val in c.items():
        if val > 1:
            print(key,val)

# %%
from datetime import datetime
current_date = datetime.now()
last_date = current_date - timedelta(days=1)
current_date_str = current_date.strftime("%Y%m%d")
last_date_str = last_date.strftime("%Y%m%d")

# %%
# Out:
# {'Agriculture': 1,
#  ' agricultural': 1,
#  ' farming': 1,
#  ' เกษตร': 1,
#  ' เกษตรกรรม': 1,
#  ' กสิกรรม': 1,
#  ' การเพาะปลูก': 1,
#  ' การทำไร่ทำนา': 1,
#  ' การทำการเกษตร': 1,
#  'Anthracite': 1,
#  ' แอนทราไซต์': 1,
#  ' ถ่านหินชนิดแข็ง': 1,
#  ' ถ่านหินคุณภาพสูง': 1,
#  'Bagasse': 1,
#  ' ชานอ้อย': 1,
#  ' กากอ้อย': 1,
#  'Benzene': 1,
#  ' เบนซีน': 1,
#  ' เบนซิน': 3,
#  ' เบนซอล': 1,
#  'Biogas': 1,
#  ' ไบโอแก๊ส': 1,
#  ' ก๊าซชีวภาพ': 1,
#  ' แก๊สชีวภาพ': 1,
#  'Caprolactam': 1,
#  ' คาโพรแลคแทม': 1,
#  ' แคปโรแลคแตม': 1,
#  'Carbon dioxide': 1,
#  ' CO2': 1,
#  ' คาร์บอนไดออกไซด์': 1,
#  ' ก๊าซคาร์บอนไดออกไซด์': 1,
#  'Cob': 1,
#  ' ฝักข้าวโพด': 1,
#  ' แกนข้าวโพด': 1,
#  ' ซังข้าวโพด': 1,
#  'Compressed Natural Gas': 1,
#  ' CNG': 1,
#  ' NGV': 1,
#  ' ก๊าซธรรมชาติอัด': 1,
#  ' ก๊าซเอ็นจีวี': 1,
#  ' ก๊าซธรรมชาติสำหรับยานยนต์': 1,
#  'Cyclohexane': 1,
#  ' ไซโคลเฮกเซน': 1,
#  'Diesel': 1,
#  ' น้ำมันดีเซล': 2,
#  ' ดีเซล': 2,
#  'Ethane': 1,
#  ' อีเทน': 1,
#  ' ก๊าซอีเทน': 1,
#  'Ethylene': 1,
#  ' C2H4': 1,
#  ' เอทิลีน': 1,
#  ' ก๊าซเอทิลีน': 1,
#  'FUEL WOOD': 1,
#  ' ฟืน': 1,
#  ' เชื้อเพลิงไม้': 1,
#  ' ไม้ฟืน': 1,
#  'Forestry': 1,
#  ' ป่าไม้': 1,
#  ' วนศาสตร์': 1,
#  ' การป่าไม้': 1,
#  ' การทำป่าไม้': 1,
#  'Fuel oil': 1,
#  ' น้ำมันเตา': 1,
#  ' เชื้อเพลิงน้ำมัน': 1,
#  'Gas': 1,
#  ' ก๊าซ': 1,
#  ' แก๊ส': 1,
#  'Diesel oil': 1,
#  'Gasoline': 1,
#  ' น้ำมันเบนซิน': 2,
#  ' แก๊สโซลีน': 1,
#  'Household': 1,
#  ' ครัวเรือน': 1,
#  ' บ้านเรือน': 1,
#  ' ที่อยู่อาศัย': 1,
#  'Industry': 1,
#  ' อุตสาหกรรม': 1,
#  ' โรงงาน': 1,
#  ' โรงงานอุตสาหกรรม': 1,
#  'Jet Kerosene': 1,
#  ' น้ำมันเครื่องบิน': 1,
#  ' น้ำมันอากาศยาน': 1,
#  ' เชื้อเพลิงอากาศยาน': 1,
#  ' เจ็ทฟูเอล': 1,
#  'LPG': 1,
#  ' Liquefied Petroleum Gas': 2,
#  ' ก๊าซปิโตรเลียมเหลว': 1,
#  ' ก๊าซแอลพีจี': 1,
#  ' ก๊าซหุงต้ม': 1,
#  'Lignite': 1,
#  ' ลิกไนต์': 1,
#  ' ถ่านหินลิกไนต์': 1,
#  ' ถ่านหินสีน้ำตาล': 1,
#  'Methane': 1,
#  ' CH4': 1,
#  ' มีเทน': 1,
#  ' ก๊าซมีเทน': 1,
#  'Mixed C4': 1,
#  ' มิกซ์ซีโฟร์': 1,
#  ' ไฮโดรคาร์บอนผสม C4': 1,
#  'Motor gasoline': 1,
#  'Naphtha': 1,
#  ' แนฟทา': 1,
#  ' น้ำมันแนฟทา': 1,
#  'Natural gas': 1,
#  ' ก๊าซธรรมชาติ': 2,
#  'P-xylene': 1,
#  ' พาราไซลีน': 1,
#  ' พี-ไซลีน': 1,
#  'Ployvinyl Chloride': 1,
#  ' PVC': 1,
#  ' พีวีซี': 1,
#  ' พอลิไวนิลคลอไรด์': 1,
#  'Polypropylene': 1,
#  ' PP': 1,
#  ' พอลิโพรพิลีน': 1,
#  ' โพลีโพรพิลีน': 1,
#  'Propane': 1,
#  ' โพรเพน': 1,
#  ' ก๊าซโพรเพน': 1,
#  'Propylene': 1,
#  ' โพรพิลีน': 1,
#  ' โพรพีน': 1,
#  'Styrene Acrylonitrile': 1,
#  ' SAN': 1,
#  ' สไตรีนอะคริโลไนไตรล์': 1,
#  'Styrene Monomer': 1,
#  ' สไตรีนโมโนเมอร์': 1,
#  'Sub-bituminous coal': 1,
#  ' ถ่านหินซับบิทูมินัส': 1,
#  ' ถ่านหินกึ่งแข็ง': 1,
#  'Sulfur': 1,
#  ' กำมะถัน': 2,
#  ' ซัลเฟอร์': 1,
#  'Toluene': 1,
#  ' โทลูอีน': 1,
#  ' เมทิลเบนซีน': 1,
#  'กระจกนิรภัย': 1,
#  ' Safety Glass': 1,
#  ' Tempered Glass': 1,
#  ' Laminated Glass': 1,
#  ' กระจกเทมเปอร์': 1,
#  ' กระจกลามิเนต': 1,
#  'กระจกแผ่นเรียบ': 1,
#  ' Flat Glass': 1,
#  ' Float Glass': 1,
#  ' Sheet Glass': 1,
#  ' Plate Glass': 1,
#  'กระดาษกล่อง': 1,
#  ' กระดาษลัง': 1,
#  ' กล่องกระดาษ': 1,
#  ' กระดาษสำหรับทำกล่อง': 1,
#  ' Boxboard': 1,
#  ' Cardboard': 1,
#  ' Packaging paper': 1,
#  'กระดาษคราฟท์': 1,
#  ' กระดาษสีน้ำตาล': 1,
#  ' กระดาษห่อของ': 1,
#  ' กระดาษรีไซเคิล': 1,
#  ' Kraft paper': 1,
#  ' Brown paper': 1,
#  ' Recycled paper': 1,
#  'กระดาษพิมพ์เขียน': 1,
#  ' กระดาษเขียน': 1,
#  ' กระดาษสำหรับเขียน': 1,
#  ' กระดาษพิมพ์': 1,
#  ' Writing paper': 1,
#  ' Printing paper': 1,
#  'กระดาษหนังสือพิมพ์': 1,
#  ' กระดาษพิมพ์หนังสือพิมพ์': 1,
#  ' กระดาษสำหรับหนังสือพิมพ์': 1,
#  ' กระดาษข่าว': 1,
#  ' Newsprint': 1,
#  ' Newspaper paper': 1,
#  'กระถินสดอินทรีย์': 1,
#  ' กระถินสด': 1,
#  ' กระถินออร์แกนิก': 1,
#  ' กระถินเกษตรอินทรีย์': 1,
#  ' Fresh Leucaena': 1,
#  ' Organic Leucaena': 1,
#  ' Organic Fresh Leucaena': 1,
#  'กระเจี๊ยบเขียว': 1,
#  ' กระเจี๊ยบ': 1,
#  ' กระเจี๊ยบเขียวสด': 1,
#  ' Okra': 1,
#  ' Fresh okra': 1,
#  'กระเทียม': 1,
#  ' หัวกระเทียม': 1,
#  ' กระเทียมสด': 1,
#  ' Garlic': 1,
#  ' Fresh garlic': 1,
#  ' Garlic bulb': 1,
#  'กลีเซอรีน': 1,
#  ' กลีเซอรอล': 1,
#  ' กลีเซอรีนบริสุทธิ์': 1,
#  ' Glycerin': 1,
#  ' Glycerol': 1,
#  ' Pure glycerin': 1,
#  'น้ำประปา': 1,
#  ' น้ำใช้งาน': 1,
#  ' น้ำสะอาด': 1,
#  ' Tap water': 1,
#  ' Clean water': 1,
#  ' Drinking water': 1,
#  'ปศุสัตว์': 1,
#  ' สัตว์เลี้ยงในฟาร์ม': 1,
#  ' การเลี้ยงสัตว์': 1,
#  ' Livestock': 1,
#  ' Farm animals': 1,
#  'ปิโตรเคมี': 1,
#  ' อุตสาหกรรมปิโตรเคมี': 1,
#  ' เคมีภัณฑ์จากปิโตรเลียม': 1,
#  ' Petrochemicals': 1,
#  ' Petrochemical industry': 1,
#  'ผลิตภัณฑ์จากก๊าซธรรมชาติ': 1,
#  ' ผลิตภัณฑ์ก๊าซธรรมชาติ': 1,
#  ' ก๊าซธรรมชาติแปรรูป': 1,
#  ' Natural gas products': 1,
#  ' Processed natural gas': 1,
#  'อาหารสัตว์': 1,
#  ' อาหารเลี้ยงสัตว์': 1,
#  ' อาหารสำหรับสัตว์': 1,
#  ' Animal feed': 1,
#  ' Livestock feed': 1,
#  'อุตสาหกรรมยางธรรมชาติ': 1,
#  ' ยางธรรมชาติ': 1,
#  ' อุตสาหกรรมยาง': 1,
#  ' Natural rubber industry': 1,
#  ' Rubber industry': 1,
#  ' Natural rubber': 1,
#  'กอุตสาหกรรมโรงเลื่อยและโรงอบไม้ยางพารา': 1,
#  ' โรงเลื่อย': 1,
#  ' โรงอบไม้': 1,
#  ' โรงงานไม้ยางพารา': 1,
#  ' Rubberwood sawmill': 1,
#  ' Rubberwood drying factory': 1,
#  'เคมีภัณฑ์': 1,
#  ' สารเคมี': 1,
#  ' เคมีภัณฑ์อุตสาหกรรม': 1,
#  ' Chemicals': 1,
#  ' Chemical products': 1,
#  ' Industrial chemicals': 1,
#  'เยื่อกระดาษ': 1,
#  ' เยื่อ': 1,
#  ' กระดาษเยื่อ': 1,
#  ' Pulp': 1,
#  ' Paper pulp': 2,
#  ' Cellulose pulp': 1,
#  'ไฟฟ้า': 1,
#  ' พลังงานไฟฟ้า': 1,
#  ' กระแสไฟฟ้า': 1,
#  ' Electricity': 1,
#  ' Electric power': 1,
#  ' Electrical energy': 1,
#  'ไหมหัตถกรรม': 1,
#  ' ผ้าไหม': 1,
#  ' ไหมพื้นเมือง': 1,
#  ' Handicraft silk': 1,
#  ' Silk': 1,
#  ' Traditional silk': 1,
#  'กล้วยหอม': 1,
#  ' กล้วย': 2,
#  ' กล้วยหอมทอง': 1,
#  ' Cavendish banana': 1,
#  ' Banana': 2,
#  ' Golden banana': 1,
#  'กล้วยไข่': 1,
#  ' กล้วยพื้นเมือง': 1,
#  ' Egg banana': 1,
#  ' Native banana': 1,
#  'กล้ายางชำถุง': 1,
#  ' ต้นกล้ายางพารา': 1,
#  ' ยางพาราชำถุง': 1,
#  ' Rubber sapling in bag': 1,
#  ' Rubber tree seedling': 1,
#  ' Bagged rubber sapling': 1,
#  'กะลาปาล์ม': 1,
#  ' กะลามะพร้าวปาล์ม': 1,
#  ' กะลาปาล์มดิบ': 1,
#  ' Palm kernel shell': 1,
#  ' PKS': 1,
#  ' Raw palm shell': 1,
#  'กะหล่ำดอก': 1,
#  ' ดอกกะหล่ำ': 1,
#  ' กะหล่ำ': 2,
#  ' Cauliflower': 1,
#  ' Flowering cabbage': 1,
#  'กะหล่ำปลี': 1,
#  ' กะหล่ำหัว': 1,
#  ' Cabbage': 1,
#  ' Head cabbage': 1,
#  'กะเพรา': 1,
#  ' โหระพากะเพรา': 1,
#  ' กะเพราไทย': 1,
#  ' Holy basil': 1,
#  ' Thai basil': 1,
#  ' Ocimum sanctum': 1,
#  'กากถั่วเหลือง': 1,
#  ' ถั่วเหลืองบด': 1,
#  ' กากโปรตีนถั่วเหลือง': 1,
#  ' Soybean meal': 1,
#  ' Soybean protein residue': 1,
#  ' Ground soybean': 1,
#  'กาแฟอราบิกา': 1,
#  ' อราบิกา': 1,
#  ' Arabica coffee': 1,
#  ' Arabica': 1,
#  'กาแฟอราบิก้าคั่วบด': 1,
#  ' กาแฟคั่วบด': 1,
#  ' อราบิก้าคั่วบด': 1,
#  ' Arabica coffee roasted': 1,
#  ' Roasted coffee': 1,
#  ' Roasted Arabica': 1,
#  'กาแฟโรบัสตา': 1,
#  ' โรบัสตา': 1,
#  ' Robusta coffee': 1,
#  ' Robusta': 1,
#  'กิ่งไม้ ต้นหญ้าจากสวน': 1,
#  ' กิ่งไม้': 1,
#  ' ต้นหญ้า': 1,
#  ' กิ่งไม้จากสวน': 1,
#  ' ต้นหญ้าจากสวน': 1,
#  ' Branches and grass from garden': 1,
#  ' Garden branches': 1,
#  ' Garden grass': 1,
#  'กิ่งไม้ยางพารา': 1,
#  ' กิ่งไม้ยาง': 1,
#  ' กิ่งยางพารา': 1,
#  ' Rubber tree branches': 1,
#  ' Rubberwood branches': 1,
#  ' Rubber branches': 1,
#  'ก๊าซธรรมชาติแบบผสม': 1,
#  ' ก๊าซผสม': 1,
#  ' Mixed natural gas': 1,
#  ' Natural gas blend': 1,
#  ' Gas mixture': 1,
#  'ก๊าซหุงต้ม': 1,
#  ' แอลพีจี': 1,
#  ' ก๊าซหุงต้มแอลพีจี': 1,
#  ' LPG': 1,
#  ' Cooking gas': 1,
#  'ขวดแก้วสีชา': 1,
#  ' ขวดแก้ว': 2,
#  ' ขวดสีชา': 1,
#  ' Brown glass bottle': 1,
#  ' Amber glass bottle': 1,
#  'ขวดแก้วใส': 1,
#  ' ขวดใส': 1,
#  ' Clear glass bottle': 1,
#  ' Transparent glass bottle': 1,
#  'ขิง': 1,
#  ' ขิงสด': 1,
#  ' ขิงแห้ง': 1,
#  ' Ginger': 1,
#  ' Fresh ginger': 1,
#  ' Dried ginger': 1,
#  'ขี้เลื่อยไม้': 1,
#  ' ขี้เลื่อย': 1,
#  ' ขี้เลื่อยไม้แปรรูป': 1,
#  ' Sawdust': 2,
#  ' Wood sawdust': 1,
#  ' Processed sawdust': 1,
#  'ข่า': 1,
#  ' ข่าสด': 1,
#  ' ข่าแห้ง': 1,
#  ' Galangal': 1,
#  ' Fresh galangal': 1,
#  ' Dried galangal': 1,
#  'ข้าวฟ่างหวาน': 1,
#  ' ข้าวฟ่าง': 2,
#  ' ข้าวฟ่างสำหรับน้ำตาล': 1,
#  ' Sweet sorghum': 1,
#  ' Sorghum for sugar': 1,
#  ' Sorghum': 1,
#  'ข้าวฟ่างเลี้ยงสัตว์': 1,
#  ' ข้าวฟ่างอาหารสัตว์': 1,
#  ' Forage sorghum': 1,
#  ' Sorghum for feed': 1,
#  ' Animal feed sorghum': 1,
#  'ข้าวโพดฝักอ่อน': 1,
#  ' ข้าวโพด': 2,
#  ' ฝักอ่อนข้าวโพด': 1,
#  ' Baby corn': 1,
#  ' Young corn': 1,
#  ' Corn shoot': 1,
#  'ข้าวโพดหวาน': 1,
#  ' ข้าวโพดสำหรับบริโภค': 1,
#  ' Sweet corn': 1,
#  ' Edible corn': 1,
#  ' Corn': 1,
#  'คาร์บอนไฟเบอร์': 1,
#  ' ไฟเบอร์คาร์บอน': 1,
#  ' เส้นใยคาร์บอน': 1,
#  ' Carbon fiber': 1,
#  ' Carbon fibre': 1,
#  ' Reinforced carbon fiber': 1,
#  'งา': 1,
#  ' เมล็ดงา': 1,
#  ' งาดำ': 1,
#  ' งาขาว': 1,
#  ' Sesame': 1,
#  ' Sesame seeds': 1,
#  ' Black sesame': 1,
#  ' White sesame': 1,
#  'ฉนวนใยแก้ว': 1,
#  ' ฉนวน': 1,
#  ' ใยแก้ว': 1,
#  ' Glass wool': 1,
#  ' Fiberglass insulation': 1,
#  ' Glass fiber insulation': 1,
#  'ชาอูหลง': 1,
#  ' ชา': 1,
#  ' อูหลง': 1,
#  ' Oolong tea': 1,
#  ' Tea': 1,
#  ' Wulong tea': 1,
#  'ซัลเฟอร์': 1,
#  ' ซัลเฟอร์บริสุทธิ์': 1,
#  ' Sulfur': 1,
#  ' Pure sulfur': 1,
#  ' Elemental sulfur': 1,
#  'ตะไคร้': 1,
#  ' ตะไคร้สด': 1,
#  ' ตะไคร้แห้ง': 1,
#  ' Lemongrass': 1,
#  ' Fresh lemongrass': 1,
#  ' Dried lemongrass': 1,
#  'ต้นกล้าหม่อนชำถุง': 1,
#  ' ต้นหม่อน': 1,
#  ' หม่อนชำถุง': 1,
#  ' Mulberry sapling in bag': 1,
#  ' Bagged mulberry': 1,
#  ' Mulberry seedling': 1,
#  'ถั่วดำ': 1,
#  ' เมล็ดถั่วดำ': 1,
#  ' ถั่วดำอินทรีย์': 1,
#  ' Black bean': 1,
#  ' Organic black bean': 1,
#  ' Black gram': 1,
#  'ถั่วฝักยาว': 1,
#  ' ถั่ว': 1,
#  ' ฝักยาว': 1,
#  ' Yardlong bean': 1,
#  ' Long bean': 1,
#  ' Asparagus bean': 1,
#  'ถั่วลิสง': 1,
#  ' เมล็ดถั่วลิสง': 1,
#  ' ถั่วดิน': 1,
#  ' Peanut': 1,
#  ' Groundnut': 1,
#  ' Shelled peanut': 1,
#  'ถั่วฮามาต้าสดอินทรีย์': 1,
#  ' ถั่วฮามาต้า': 1,
#  ' ฮามาต้าอินทรีย์': 1,
#  ' Organic Hamata bean': 1,
#  ' Fresh Hamata bean': 1,
#  ' Hamata legume': 1,
#  'ถั่วเขียว': 1,
#  ' เมล็ดถั่วเขียว': 1,
#  ' ถั่วเขียวอินทรีย์': 1,
#  ' Mung bean': 1,
#  ' Green gram': 1,
#  ' Organic mung bean': 1,
#  'ถั่วเหลือง': 1,
#  ' เมล็ดถั่วเหลือง': 1,
#  ' ถั่วเหลืองแห้ง': 1,
#  ' Soybean': 1,
#  ' Soya bean': 1,
#  ' Dried soybean': 1,
#  'ถั่วเหลืองฝักสด': 1,
#  ' ถั่วเหลืองสด': 1,
#  ' ฝักถั่วเหลือง': 1,
#  ' Fresh soybean pod': 1,
#  ' Fresh soybean': 1,
#  ' Green soybean': 1,
#  'ถั่วเหลืองอินทรีย์': 1,
#  ' ถั่วเหลืองออร์แกนิก': 1,
#  ' เมล็ดถั่วเหลืองอินทรีย์': 1,
#  ' Organic soybean': 1,
#  ' Organic soya bean': 1,
#  'ถั่วแขก': 1,
#  ' ถั่วฝักสด': 1,
#  ' แขกถั่ว': 1,
#  ' Snap bean': 1,
#  ' Fresh snap bean': 1,
#  ' Green bean': 1,
#  'ทุเรียน': 1,
#  ' ทุเรียนสด': 1,
#  ' ทุเรียนหมอนทอง': 1,
#  ' Durian': 1,
#  ' Fresh durian': 1,
#  ' Monthong durian': 1,
#  'นมผึ้ง': 1,
#  ' รอยัลเยลลี่': 1,
#  ' อาหารผึ้ง': 1,
#  ' Royal jelly': 1,
#  ' Bee jelly': 1,
#  ' Apiculture jelly': 1,
#  'น้ำกะทิ': 1,
#  ' กะทิ': 1,
#  ' น้ำกะทิสด': 1,
#  ' Coconut milk': 1,
#  ' Fresh coconut milk': 1,
#  ' Creamed coconut': 1,
#  'น้ำตาล': 1,
#  ' น้ำตาลทราย': 1,
#  ' น้ำตาลอ้อย': 1,
#  ' Sugar': 1,
#  ' Cane sugar': 1,
#  ' Granulated sugar': 1,
#  'น้ำนมดิบ': 1,
#  ' นมดิบ': 1,
#  ' น้ำนม': 1,
#  ' Raw milk': 1,
#  ' Fresh milk': 1,
#  ' Unprocessed milk': 1,
#  'น้ำผึ้งกรอง': 1,
#  ' น้ำผึ้ง': 1,
#  ' น้ำผึ้งแท้': 1,
#  ' Filtered honey': 1,
#  ' Pure honey': 1,
#  ' Honey': 1,
#  'น้ำมันงาสกัดเย็น': 1,
#  ' น้ำมันงา': 1,
#  ' งาสกัดเย็น': 1,
#  ' Cold-pressed sesame oil': 1,
#  ' Sesame oil': 1,
#  ' Virgin sesame oil': 1,
#  'น้ำมันปาล์มดิบ': 1,
#  ' น้ำมันปาล์ม': 1,
#  ' ปาล์มน้ำมันดิบ': 1,
#  ' Crude palm oil': 1,
#  ' Palm oil': 1,
#  ' Unrefined palm oil': 1,
#  'น้ำยางข้น': 1,
#  ' ยางพาราข้น': 1,
#  ' น้ำยางพารา': 1,
#  ' Concentrated latex': 1,
#  ' Thickened rubber latex': 1,
#  ' Rubber concentrate': 1,
#  'น้ำยางสด': 1,
#  ' น้ำยางดิบ': 1,
#  ' ยางพาราสด': 1,
#  ' Fresh latex': 1,
#  ' Raw latex': 1,
#  ' Natural rubber latex': 1,
#  'น้ำอ่อน': 1,
#  ' น้ำสำหรับซักล้าง': 1,
#  ' น้ำบริสุทธิ์': 1,
#  ' Soft water': 1,
#  ' Purified water': 1,
#  ' Washing water': 1,
#  'ปลาดุก': 1,
#  ' ปลาดุกสด': 1,
#  ' Catfish': 1,
#  ' Fresh catfish': 1,
#  ' Farmed catfish': 1,
#  'ปลาทับทิม': 1,
#  ' ทับทิมปลา': 1,
#  ' Nile tilapia': 2,
#  ' Red tilapia': 1,
#  ' Fresh tilapia': 2,
#  'ปลานิล': 1,
#  ' ปลานิลสด': 1,
#  ' Tilapia': 1,
#  'ปลาป่น': 1,
#  ' โปรตีนปลาป่น': 1,
#  ' ปลาบด': 1,
#  ' Fishmeal': 1,
#  ' Ground fish': 1,
#  ' Fish protein': 1,
#  'ปลาเป็ด': 1,
#  ' ปลาเนื้อเป็ด': 1,
#  ' ปลาสำหรับอาหารสัตว์': 1,
#  ' Duck fish': 1,
#  ' Fish for feed': 1,
#  ' Feed fish': 1,
#  'ปาล์มน้ำมัน': 1,
#  ' ผลปาล์มน้ำมัน': 2,
#  ' Palm oil fruit': 1,
#  ' Oil palm': 1,
#  ' Palm kernel fruit': 1,
#  'ปีกไม้ยางพารา': 1,
#  ' ปีกไม้': 1,
#  ' ยางพาราแปรรูป': 2,
#  ' Rubberwood wings': 1,
#  ' Processed rubberwood': 3,
#  ' Rubberwood offcuts': 1,
#  'ผลปาล์มทะลายสด': 1,
#  ' ทะลายปาล์มสด': 1,
#  ' Fresh oil palm fruit bunch': 1,
#  ' Fresh palm bunch': 1,
#  ' Oil palm bunch': 1,
#  'ผลมะกรูด': 1,
#  ' มะกรูดสด': 1,
#  ' มะกรูดผล': 1,
#  ' Kaffir lime fruit': 1,
#  ' Fresh kaffir lime': 1,
#  ' Lime fruit': 1,
#  'ผักกาดหอม': 1,
#  ' ผักกาด': 1,
#  ' ผักสลัด': 1,
#  ' Lettuce': 1,
#  ' Salad lettuce': 1,
#  ' Green lettuce': 1,
#  'ผักกาดหัว': 1,
#  ' หัวไชเท้า': 1,
#  ' ผักกาดไชเท้า': 1,
#  ' Daikon': 1,
#  ' Radish': 1,
#  ' White radish': 1,
#  'ผักกาดเขียวกวางตุ้ง': 1,
#  ' ผักกวางตุ้ง': 1,
#  ' กวางตุ้ง': 1,
#  ' Bok choy': 1,
#  ' Chinese mustard': 1,
#  ' Green mustard': 1,
#  'ผักคะน้า': 1,
#  ' คะน้า': 1,
#  ' คะน้าสด': 1,
#  ' Chinese kale': 1,
#  ' Kale': 1,
#  ' Fresh kale': 1,
#  'ผิวมะกรูด': 1,
#  ' เปลือกมะกรูด': 1,
#  ' ผิวมะกรูดสด': 1,
#  ' Kaffir lime peel': 1,
#  ' Lime skin': 1,
#  ' Fresh kaffir lime peel': 1,
#  'ผ้า': 1,
#  ' ผ้าผืน': 1,
#  ' สิ่งทอ': 1,
#  ' Fabric': 3,
#  ' Cloth': 1,
#  ' Textile': 2,
#  'ผ้าถัก': 1,
#  ' ผ้าทอถัก': 1,
#  ' สิ่งทอถัก': 1,
#  ' Knitted fabric': 1,
#  ' Knitwear': 1,
#  ' Knitted textile': 1,
#  'ผ้าถักจากเส้นด้ายฝ้าย': 1,
#  ' ผ้าถักฝ้าย': 1,
#  ' สิ่งทอถักฝ้าย': 1,
#  ' Cotton knitted fabric': 2,
#  ' Knitted cotton': 2,
#  ' Cotton textile': 2,
#  'ผ้าถักจากเส้นด้ายโพลีเอสเตอร์': 1,
#  ' ผ้าถักโพลิเอสเตอร์': 1,
#  ' สิ่งทอถักโพลีเอสเตอร์': 1,
#  ' Polyester knitted fabric': 2,
#  ' Knitted polyester': 2,
#  ' Polyester textile': 2,
#  'ผ้าถักฝ้าย': 1,
#  ' ผ้าฝ้ายถัก': 1,
#  ' ผ้าถักจากฝ้าย': 1,
#  ' Cotton fabric': 2,
#  'ผ้าถักโพลิเอสเทอร์': 1,
#  ' ผ้าโพลิเอสเทอร์ถัก': 1,
#  ' สิ่งทอถักโพลิเอสเทอร์': 1,
#  ' Polyester fabric': 2,
#  'ผ้าทอ': 1,
#  ' สิ่งทอทอ': 1,
#  ' ผ้าผืนทอ': 1,
#  ' Woven fabric': 1,
#  ' Woven textile': 1,
#  'ผ้าทอจากเส้นด้ายฝ้าย': 1,
#  ' ผ้าทอฝ้าย': 1,
#  ' ผ้าฝ้ายทอ': 2,
#  ' Cotton woven fabric': 2,
#  ' Woven cotton': 2,
#  'ผ้าทอจากเส้นด้ายโพลีเอสเตอร์': 1,
#  ' ผ้าทอโพลิเอสเตอร์': 1,
#  ' สิ่งทอทอโพลิเอสเตอร์': 1,
#  ' Polyester woven fabric': 2,
#  ' Woven polyester': 2,
#  'ผ้าทอฝ้าย': 1,
#  ' สิ่งทอฝ้าย': 1,
#  'ผ้าทอโพลิเอสเทอร์': 1,
#  ' ผ้าโพลิเอสเทอร์ทอ': 1,
#  ' สิ่งทอโพลิเอสเทอร์': 1,
#  'ผ้าอ้อมเด็กทำด้วยกระดาษ': 1,
#  ' ผ้าอ้อมกระดาษ': 1,
#  ' ผ้าอ้อมใช้แล้วทิ้ง': 1,
#  ' Disposable baby diaper': 1,
#  ' Paper baby diaper': 1,
#  ' Baby nappy': 1,
#  'ฝรั่ง': 1,
#  ' ฝรั่งสด': 1,
#  ' ฝรั่งผลไม้': 1,
#  ' Guava': 1,
#  ' Fresh guava': 1,
#  ' Tropical guava': 1,
#  'พริกขี้หนู': 1,
#  ' พริกเล็ก': 1,
#  ' พริกเผ็ด': 1,
#  " Bird's eye chili": 1,
#  ' Thai chili': 1,
#  ' Small chili': 1,
#  'พริกชี้ฟ้า': 1,
#  ' พริกเม็ดใหญ่': 1,
#  ' พริกเขียวชี้ฟ้า': 1,
#  ' Long chili': 1,
#  ' Green chili': 1,
#  ' Large chili': 1,
#  'พริกชี้ฟ้าแดง': 1,
#  ' พริกแดงชี้ฟ้า': 1,
#  ' พริกแดงเม็ดใหญ่': 1,
#  ' Red long chili': 1,
#  ' Red chili': 1,
#  ' Large red chili': 1,
#  'พริกหวาน': 1,
#  ' พริกหยวกหวาน': 1,
#  ' พริกสลัด': 1,
#  ' Bell pepper': 1,
#  ' Sweet pepper': 1,
#  ' Capsicum': 1,
#  'พริกไทย': 1,
#  ' เมล็ดพริกไทย': 1,
#  ' พริกไทยสด': 1,
#  ' Pepper': 1,
#  ' Fresh pepper': 1,
#  ' Peppercorn': 1,
#  'มะนาว': 1,
#  ' มะนาวสด': 1,
#  ' มะนาวผล': 1,
#  ' Lime': 1,
#  ' Fresh lime': 1,
#  ' Citrus lime': 1,
#  'มะพร้าว': 1,
#  ' มะพร้าวผล': 1,
#  ' มะพร้าวแก่': 1,
#  ' Coconut': 1,
#  ' Mature coconut': 1,
#  ' Tropical coconut': 1,
#  'มะพร้าวน้ำหอม': 1,
#  ' มะพร้าวสด': 1,
#  ' มะพร้าวน้ำหอมผล': 1,
#  ' Aromatic coconut': 1,
#  ' Fragrant coconut': 1,
#  ' Fresh aromatic coconut': 1,
#  'มะม่วง': 1,
#  ' มะม่วงสุก': 1,
#  ' มะม่วงดิบ': 1,
#  ' Mango': 1,
#  ' Ripe mango': 1,
#  ' Green mango': 1,
#  'มะเขือพวง': 1,
#  ' มะเขือพวงสด': 1,
#  ' มะเขือป่า': 1,
#  ' Pea eggplant': 1,
#  ' Turkey berry': 1,
#  ' Fresh pea eggplant': 1,
#  'มะเขือเทศ': 1,
#  ' มะเขือเทศสด': 1,
#  ' มะเขือเทศผล': 1,
#  ' Tomato': 1,
#  ' Fresh tomato': 1,
#  ' Ripe tomato': 1,
#  'มังคุด': 1,
#  ' มังคุดสด': 1,
#  ' ราชินีผลไม้': 1,
#  ' Mangosteen': 1,
#  ' Fresh mangosteen': 1,
#  ' Queen of fruits': 1,
#  'มันฝรั่ง': 1,
#  ' มันฝรั่งสด': 1,
#  ' มันฝรั่งหัว': 1,
#  ' Potato': 1,
#  ' Fresh potato': 1,
#  ' Potato tuber': 1,
#  'มันสำปะหลัง': 1,
#  ' มันสำปะหลังสด': 1,
#  ' มันสำปะหลังหัว': 1,
#  ' Cassava': 1,
#  ' Fresh cassava': 1,
#  ' Tapioca root': 1,
#  'ยางก้อนถ้วย': 1,
#  ' ยางก้อน': 1,
#  ' ยางพาราก้อนถ้วย': 1,
#  ' Cup lump rubber': 1,
#  ' Rubber lump': 1,
#  ' Natural rubber cup': 1,
#  'ยางสกิม': 1,
#  ' ยางพาราสกิม': 1,
#  ' ยางสกิมมิ่ง': 1,
#  ' Skim rubber': 1,
#  ' Rubber skim': 1,
#  ' Skimmed rubber': 1,
#  'รังไหม': 1,
#  ' รังไหมสด': 1,
#  ' รังไหมแห้ง': 1,
#  ' Silk cocoon': 1,
#  ' Fresh cocoon': 1,
#  ' Dried cocoon': 1,
#  'รากผักชี': 1,
#  ' ผักชีราก': 1,
#  ' รากสดผักชี': 1,
#  ' Coriander root': 1,
#  ' Fresh coriander root': 1,
#  ' Cilantro root': 1,
#  'ลองกอง': 1,
#  ' ลองกองสด': 1,
#  ' ผลลองกอง': 1,
#  ' Longkong': 1,
#  ' Fresh longkong': 1,
#  ' Langsat': 1,
#  'ลำไยนอกฤดู': 1,
#  ' ลำไยสดนอกฤดู': 1,
#  ' ผลลำไยนอกฤดู': 1,
#  ' Off-season longan': 1,
#  ' Fresh off-season longan': 1,
#  ' Longan': 2,
#  'ลำไยในฤดู': 1,
#  ' ลำไยสดในฤดู': 1,
#  ' ผลลำไยในฤดู': 1,
#  ' In-season longan': 1,
#  ' Fresh in-season longan': 1,
#  'ลิ้นจี่': 1,
#  ' ลิ้นจี่สด': 1,
#  ' ผลลิ้นจี่': 1,
#  ' Lychee': 1,
#  ' Fresh lychee': 1,
#  ' Litchi': 1,
#  'สตรอเบอรี่': 1,
#  ' สตรอเบอร์รี่สด': 1,
#  ' สตรอเบอร์รี่ผล': 1,
#  ' Strawberry': 1,
#  ' Fresh strawberry': 1,
#  ' Berry': 1,
#  'สับปะรดผลสด': 1,
#  ' สับปะรด': 1,
#  ' สับปะรดสด': 1,
#  ' Fresh pineapple': 1,
#  ' Pineapple': 1,
#  ' Tropical pineapple': 1,
#  'สับปะรดโรงงาน': 1,
#  ' สับปะรดแปรรูป': 1,
#  ' สับปะรดสำหรับโรงงาน': 1,
#  ' Processed pineapple': 1,
#  ' Factory-grade pineapple': 1,
#  ' Pineapple for industry': 1,
#  'สิ่งทอ': 1,
#  ' ผ้าทอ': 1,
#  ' อุตสาหกรรมสิ่งทอ': 1,
#  ' Textile industry': 1,
#  'สีธรรมชาติ': 1,
#  ' สีจากธรรมชาติ': 1,
#  ' สีธรรมชาติสำหรับผ้า': 1,
#  ' Natural dye': 1,
#  ' Plant-based dye': 1,
#  ' Eco-friendly dye': 1,
#  'สุกรขุนชำแหละ': 1,
#  ' สุกรชำแหละ': 1,
#  ' เนื้อหมูขุนชำแหละ': 1,
#  ' Slaughtered pig': 1,
#  ' Pork carcass': 1,
#  ' Pig carcass': 1,
#  'สุกรขุนชำแหละอื่นๆ': 1,
#  ' สุกรแปรรูป': 1,
#  ' เนื้อสุกรแปรรูป': 1,
#  ' Processed pig': 1,
#  ' Processed pork': 1,
#  ' Pork product': 1,
#  'สุกรขุนมีชีวิต': 1,
#  ' หมูขุน': 1,
#  ' สุกรขุนฟาร์ม': 1,
#  ' Live fattened pig': 1,
#  ' Live pig': 1,
#  ' Farm-raised pig': 1,
#  'ส้มเขียวหวาน': 1,
#  ' ส้มเขียวหวานสด': 1,
#  ' ส้มผลสด': 1,
#  ' Tangerine': 1,
#  ' Fresh tangerine': 1,
#  ' Mandarin orange': 1,
#  'ส้มโอ': 1,
#  ' ส้มโอสด': 1,
#  ' ส้มโอผล': 1,
#  ' Pomelo': 1,
#  ' Fresh pomelo': 1,
#  ' Shaddock': 1,
#  'หญ้ากินนีสดอินทรีย์': 1,
#  ' หญ้ากินนี': 1,
#  ' หญ้าอินทรีย์': 1,
#  ' Organic guinea grass': 1,
#  ' Fresh guinea grass': 1,
#  ' Guinea grass': 1,
#  'หญ้ากินนีอินทรีย์ หมักด้วยไซโล': 1,
#  ' หญ้ากินนีหมักไซโล': 1,
#  ' หญ้าอินทรีย์หมักไซโล': 1,
#  ' Silage guinea grass': 1,
#  ' Organic silage grass': 1,
#  ' Guinea grass silage': 1,
#  'หญ้ารูซี่สดอินทรีย์': 1,
#  ' หญ้ารูซี่': 1,
#  ' หญ้าอินทรีย์รูซี่': 1,
#  ' Organic ruzigrass': 1,
#  ' Fresh ruzigrass': 1,
#  ' Ruzigrass': 1,
#  'หญ้าเนเปียร์สดอินทรีย์': 1,
#  ' หญ้าเนเปียร์': 1,
#  ' หญ้าอินทรีย์เนเปียร์': 1,
#  ' Organic napier grass': 1,
#  ' Fresh napier grass': 1,
#  ' Napier grass': 1,
#  'หญ้าแพงโกล่าสดอินทรีย์': 1,
#  ' หญ้าแพงโกล่า': 1,
#  ' หญ้าอินทรีย์แพงโกล่า': 1,
#  ' Organic pangola grass': 1,
#  ' Fresh pangola grass': 1,
#  ' Pangola grass': 1,
#  'หนังโคสด': 1,
#  ' หนังวัว': 1,
#  ' หนังโค': 1,
#  ' Fresh cowhide': 1,
#  ' Cow leather': 1,
#  ' Fresh cattle hide': 1,
#  'หน่อไม้': 1,
#  ' หน่อไม้สด': 1,
#  ' Bamboo shoot': 1,
#  ' Fresh bamboo shoot': 1,
#  ' Edible bamboo shoot': 1,
#  'หน่อไม้ฝรั่ง': 1,
#  ' หน่อฝรั่ง': 1,
#  ' หน่อไม้สดฝรั่ง': 1,
#  ' Asparagus': 1,
#  ' Fresh asparagus': 1,
#  ' Asparagus spear': 1,
#  'หม่อนผลสด ปลูกแบบทั่วไป': 1,
#  ' หม่อนผลสด': 1,
#  ' ผลหม่อน': 1,
#  ' Fresh mulberry': 1,
#  ' Mulberry fruit': 1,
#  ' General mulberry': 1,
#  'หอมหัวใหญ่': 1,
#  ' หอมใหญ่': 1,
#  ' หัวหอมใหญ่': 1,
#  ' Onion': 1,
#  ' Big onion': 1,
#  ' Bulb onion': 1,
#  'หอมแดง': 1,
#  ' หอมเล็ก': 1,
#  ' หัวหอมแดง': 1,
#  ' Shallot': 1,
#  ' Red onion': 1,
#  ' Small onion': 1,
#  'หอยหลอด': 1,
#  ' หลอดหอย': 1,
#  ' Razor clam': 1,
#  ' Bamboo clam': 1,
#  ' Fresh razor clam': 1,
#  'หอยหวาน': 1,
#  ' หอยน้ำเค็มหวาน': 1,
#  ' Sweet snail': 1,
#  ' Sweet sea snail': 1,
#  ' Fresh sweet snail': 1,
#  'หอยแครง': 1,
#  ' หอยน้ำเค็มแครง': 1,
#  ' Cockle': 1,
#  ' Fresh cockle': 1,
#  ' Blood cockle': 1,
#  'หอยแมลงภู่': 1,
#  ' หอยน้ำเค็มแมลงภู่': 1,
#  ' Mussel': 1,
#  ' Fresh mussel': 1,
#  ' Green mussel': 1,
#  'องุ่น': 1,
#  ' องุ่นสด': 1,
#  ' Grapes': 1,
#  ' Fresh grapes': 1,
#  ' Table grapes': 1,
#  'อาหารข้นโคนมอินทรีย์': 1,
#  ' อาหารโคนม': 1,
#  ' อาหารอินทรีย์': 1,
#  ' Organic dairy feed': 1,
#  ' Concentrated dairy feed': 1,
#  ' Dairy cattle feed': 1,
#  'อาหารสุกรขุน': 1,
#  ' อาหารหมูขุน': 1,
#  ' อาหารสำหรับหมู': 1,
#  ' Pig fattening feed': 1,
#  ' Hog feed': 1,
#  ' Pork feed': 1,
#  'อาหารไก่': 1,
#  ' อาหารสำหรับไก่': 1,
#  ' Chicken feed': 1,
#  ' Poultry feed': 1,
#  ' Bird feed': 1,
#  'อาหารไก่ไข่': 1,
#  ' อาหารไก่': 1,
#  ' อาหารไก่เลี้ยงไข่': 1,
#  ' Layer chicken feed': 1,
#  ' Egg chicken feed': 1,
#  ' Layer feed': 1,
#  'อ้อยคั้นน้ำ': 1,
#  ' อ้อยสด': 1,
#  ' อ้อยคั้น': 1,
#  ' Sugarcane': 1,
#  ...}
