# %%
import json
import pandas as pd

with open('combine_20250602.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
    df = pd.DataFrame(data)

# %%
for word in df['Name']:
    if "10 ล้อ" in word:
        print(word)
        # t = word.split()
        # print(t[0])
# Out:
# รถตู้บรรทุก 10 ล้อ วิ่งปกติ 0% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งปกติ 50% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งปกติ 75% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งปกติ 100% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งแบบสมบุกสมบัน 0% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งแบบสมบุกสมบัน 50% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งแบบสมบุกสมบัน 75% Loading
# รถตู้บรรทุก 10 ล้อ วิ่งแบบสมบุกสมบัน 100% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งปกติ 0% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งปกติ 50% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งปกติ 75% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งปกติ 100% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งแบบสมบุกสมบัน 0% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งแบบสมบุกสมบัน 50% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งแบบสมบุกสมบัน 75% Loading
# รถตู้บรรทุกเปิด 10 ล้อ วิ่งแบบสมบุกสมบัน 100% Loading
# รถกระบะบรรทุก 10 ล้อ วิ่งปกติ 0% Loading
# รถกระบะบรรทุก 10 ล้อ วิ่งปกติ 50% Loading
# รถกระบะบรรทุก 10 ล้อ วิ่งปกติ 75% Loading
# รถกระบะบรรทุก 10 ล้อ วิ่งปกติ 100% Loading
# ...
