# %%
import pandas as pd

# %%
df = pd.read_csv('CFP_Init_bk.csv')

# %%
df['วันที่อัพเดท'] = df['วันที่อัพเดท'].replace({
    'Update_Dec2019': 'Dec 2019',
    'Update_July2022': 'July 2022',
    'Update_24Sep12': 'Apr 2022',
    "Update_Mar2021": 'Mar 2021',
    'Update_09Apr15': 'Apr 2015',
    'Update_24Aug11': 'Aug 2011',
    'Update_09Oct13': 'Oct 2013',
    'New_July2022': 'July 2022',
    'Update_Apr2022': 'Apr 2022'
})

# %%
df.to_csv('CFP_CFO_Init.csv', encoding='utf-8-sig')
