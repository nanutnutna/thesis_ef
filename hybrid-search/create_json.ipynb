# %%
import pandas as pd

path = r'C:\Users\Nattapot\Desktop\thesis_ef\evaluate\emission_factor_20250324.csv'

df = pd.read_csv(path)
df.to_json('results.json',force_ascii=False, orient='records', indent=4)

# %%
path_sym = r'C:\Users\Nattapot\Desktop\thesis_ef\hybrid-search\synonyms2.csv'
df_sym = pd.read_csv(path_sym,header=0)
